# %% [markdown]
# #Results

# %% [markdown]
# ##Our simulation for only two drones cause of complexty

# %% [markdown]
# ![Screenshot_10-12-2024_173044_www.canva.com.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_10-12-2024_17309_www.canva.com.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot_10-12-2024_17315_www.canva.com.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### this is one of the simulated paths

# %% [markdown]
# ![Screenshot_11-12-2024_153912_colab.research.google.com.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Our results of the Reward process

# %% [markdown]
# ![Screenshot_11-12-2024_153938_colab.research.google.com.jpeg](data:image/jpeg;base64,...)
